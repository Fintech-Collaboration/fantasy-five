# %%
import os
import requests
import json
import numpy as np
from dotenv import load_dotenv
import pandas as pd
import sqlalchemy

#importing sql libraries
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float, Date
from sqlalchemy.orm import Session

from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

from coinapi_rest_v1.restapi import CoinAPIv1
import datetime, sys

# %%
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

# %%
load_dotenv()
# Out:
# True

# %%
coin_api_key = os.getenv("COIN_API_KEY")

# %%
type(coin_api_key)
# Out:
# str

# %%
api = CoinAPIv1(coin_api_key)

# %%
coin_api_key2 = os.getenv("COIN_API_KEY2")

# %%
type(coin_api_key2)
# Out:
# str

# %%
api2 = CoinAPIv1(coin_api_key2)

# %%
coin_api_key3 = os.getenv("COIN_API_KEY3")

# %%
type(coin_api_key3)
# Out:
# str

# %%
api3 = CoinAPIv1(coin_api_key3)

# %%
coin_api_key4 = os.getenv("COIN_API_KEY4")

# %%
type(coin_api_key4)
# Out:
# str

# %%
api4 = CoinAPIv1(coin_api_key4)

# %%
# Import necessary dependencies and libraries, set the client up
from pycoingecko import CoinGeckoAPI
import pandas as pd
cg = CoinGeckoAPI()

# %%
exchange_data = cg.get_exchanges_list()
exchange_data
# Out:
# [{'id': 'binance',
#   'name': 'Binance',
#   'year_established': 2017,
#   'country': 'Cayman Islands',
#   'description': '',
#   'url': 'https://www.binance.com/',
#   'image': 'https://assets.coingecko.com/markets/images/52/small/binance.jpg?1519353250',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 1,
#   'trade_volume_24h_btc': 464518.3001401084,
#   'trade_volume_24h_btc_normalized': 464518.3001401084},
#  {'id': 'huobi',
#   'name': 'Huobi Global',
#   'year_established': 2013,
#   'country': 'Seychelles',
#   'description': '',
#   'url': 'https://www.huobi.com',
#   'image': 'https://assets.coingecko.com/markets/images/25/small/1481589873352_.pic_hd.jpg?1589962155',
#   'has_trading_incentive': False,
#   'trust_score': 10,
#   'trust_score_rank': 2,
#   'trade_volume_24h_btc': 75047.0052719542,
#   'trade_volume_24h_btc_normalized': 75047.0052719542},
#  {'id': 'gdax',
#   'name': 'Coinbase Exchange',
#   'year_established': 2012,
# ...

# %%
trust_df =pd.DataFrame(exchange_data, columns=['name', 'trust_score','trust_score_rank'])
trust_df.set_index('name',inplace=True)
trust_df.head(25)
# Out:
#                      trust_score  trust_score_rank
# name
# Binance                       10                 1
# Huobi Global                  10                 2
# Coinbase Exchange             10                 3
# FTX                           10                 4
# Crypto.com Exchange           10                 5
# KuCoin                        10                 6
# Gate.io                       10                 7
# Kraken                        10                 8
# Binance US                    10                 9
# WOO Network                   10                10
# Gemini                        10                11
# Bitrue                         9                12
# BitMart                        9                13
# Bitstamp                       9                14
# BtcTurk PRO                    9                15
# Bithumb Global                 9                16
# BTSE                           9                17
# ...

# %%
trust_df.to_csv('data_files2/trust.csv')

# %%
trending = cg.get_search_trending()
trending
# Out:
# {'coins': [{'item': {'id': 'astroswap',
#     'coin_id': 18816,
#     'name': 'AstroSwap',
#     'symbol': 'ASTRO',
#     'market_cap_rank': 481,
#     'thumb': 'https://assets.coingecko.com/coins/images/18816/thumb/astro.png?1633506850',
#     'small': 'https://assets.coingecko.com/coins/images/18816/small/astro.png?1633506850',
#     'large': 'https://assets.coingecko.com/coins/images/18816/large/astro.png?1633506850',
#     'slug': 'astroswap',
#     'price_btc': 5.766107769277958e-06,
#     'score': 0}},
#   {'item': {'id': 'taboo-token',
#     'coin_id': 6111,
#     'name': 'Taboo Token',
#     'symbol': 'TABOO',
#     'market_cap_rank': 367,
#     'thumb': 'https://assets.coingecko.com/coins/images/6111/thumb/taboo.PNG?1624500776',
#     'small': 'https://assets.coingecko.com/coins/images/6111/small/taboo.PNG?1624500776',
#     'large': 'https://assets.coingecko.com/coins/images/6111/large/taboo.PNG?1624500776',
#     'slug': 'taboo-token',
# ...

# %%
type(trending)
# Out:
# dict

# %%
# Trending Coins
trending_df = pd.json_normalize(trending['coins'])
# trending_df.set_index('name',inplace=True)
trending_df.head(10)
# Out:
#         item.id  item.coin_id     item.name item.symbol  item.market_cap_rank  \
# 0     astroswap         18816     AstroSwap       ASTRO                   481
# 1   taboo-token          6111   Taboo Token       TABOO                   367
# 2  reef-finance         13504  Reef Finance        REEF                   227
# 3      polkadot         12171      Polkadot         DOT                     8
# 4      kuma-inu         15526      Kuma Inu        KUMA                   647
# 5         ariva         18103         Ariva         ARV                   590
# 6       safepal         13905       SafePal         SFP                   238
#
#                                           item.thumb  \
# 0  https://assets.coingecko.com/coins/images/1881...
# 1  https://assets.coingecko.com/coins/images/6111...
# 2  https://assets.coingecko.com/coins/images/1350...
# 3  https://assets.coingecko.com/coins/images/1217...
# 4  https://assets.coingecko.com/coins/images/1552...
# ...

# %%
trending_df.drop(columns=
    ['item.id', 'item.coin_id', 'item.thumb', 'item.small', 'item.large', 'item.large', 'item.score', 'item.slug']).rename(columns={'item.name' : 'Coin', 'item.symbol' : 'Ticker', 'item.market_cap_rank' : 'market_cap_rank', 'item.price_btc' : 'price_btc'})
# Out:
#            Coin Ticker  market_cap_rank     price_btc
# 0     AstroSwap  ASTRO              481  5.766108e-06
# 1   Taboo Token  TABOO              367  2.444212e-07
# 2  Reef Finance   REEF              227  3.821484e-07
# 3      Polkadot    DOT                8  6.949606e-04
# 4      Kuma Inu   KUMA              647  6.369574e-12
# 5         Ariva    ARV              590  1.625344e-08
# 6       SafePal    SFP              238  4.370077e-05

# %%
trending_df.to_csv('data_files2/trending_coins.csv')

# %%
#Bitcoin 24hr mkt. Cap and Volume
btc = cg.get_price(
    ids='bitcoin', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
eth = cg.get_price(
    ids='ethereum', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
ada = cg.get_price(
    ids='cardano', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
usdt = cg.get_price(
    ids='tether', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
atom = cg.get_price(
    ids='cosmos', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
rep = cg.get_price(
    ids='augur', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
bal = cg.get_price(
    ids='balancer', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
xtz = cg.get_price(
    ids='tezos', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
aave = cg.get_price(
    ids='aave', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
# Update the data with parameters: 24h change, volume, market cap
ant = cg.get_price(
    ids='aragon', vs_currencies='usd', include_market_cap='true',
    include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')

# %%
btc_df = pd.DataFrame(btc)
eth_df = pd.DataFrame(eth)
ada_df = pd.DataFrame(ada)
usdt_df = pd.DataFrame(usdt)
atom_df = pd.DataFrame(atom)
rep_df = pd.DataFrame(rep)
bal_df = pd.DataFrame(bal)
xtz_df = pd.DataFrame(xtz)
aave_df = pd.DataFrame(aave)
ant_df = pd.DataFrame(ant)

# %%
btc_df.to_csv('data_files2/btc.csv')
eth_df.to_csv('data_files2/eth.csv')
ada_df.to_csv('data_files2/ada.csv')
usdt_df.to_csv('data_files2/usdt.csv')
atom_df.to_csv('data_files2/atom.csv')
rep_df.to_csv('data_files2/rep.csv')
bal_df.to_csv('data_files2/bal.csv')
xtz_df.to_csv('data_files2/xtz.csv')
aave_df.to_csv('data_files2/aave.csv')
ant_df.to_csv('data_files2/ant.csv')

# %%
bitcoin_market_data = api.ohlcv_historical_data(
    'KRAKEN_SPOT_BTC_USD', {'period_id': '1MTH',
                            'time_start': datetime.date(2016, 1, 1).isoformat() ,
                            'time_end': datetime.date(2021, 12, 31).isoformat()})

# %%
bitcoin_market_data
# Out:
# [{'time_period_start': '2016-01-01T00:00:00.0000000Z',
#   'time_period_end': '2016-02-01T00:00:00.0000000Z',
#   'time_open': '2016-01-01T04:23:22.5070000Z',
#   'time_close': '2016-01-26T20:04:30.0000000Z',
#   'price_open': 434.17899,
#   'price_high': 460.0,
#   'price_low': 351.76,
#   'price_close': 395.95,
#   'volume_traded': 6812.98123866,
#   'trades_count': 8448},
#  {'time_period_start': '2016-02-01T00:00:00.0000000Z',
#   'time_period_end': '2016-03-01T00:00:00.0000000Z',
#   'time_open': '2016-02-05T16:08:38.6570000Z',
#   'time_close': '2016-02-28T22:11:03.9330000Z',
#   'price_open': 390.44,
#   'price_high': 443.99999,
#   'price_low': 367.70524,
#   'price_close': 433.7,
#   'volume_traded': 17039.39374761,
#   'trades_count': 21464},
#  {'time_period_start': '2016-03-01T00:00:00.0000000Z',
#   'time_period_end': '2016-04-01T00:00:00.0000000Z',
#   'time_open': '2016-03-05T11:09:28.0000000Z',
#   'time_close': '2016-03-31T23:56:27.7000000Z',
# ...

# %%
coin_market = cg.get_coins_markets(vs_currency='usd')
coin_market
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 57094,
#   'market_cap': 1075858579885,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1199024487844,
#   'total_volume': 39768895774,
#   'high_24h': 57285,
#   'low_24h': 54409,
#   'price_change_24h': 1250.73,
#   'price_change_percentage_24h': 2.23974,
#   'market_cap_change_24h': 23921743206,
#   'market_cap_change_percentage_24h': 2.27407,
#   'circulating_supply': 18842843.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 64805,
#   'ath_change_percentage': -11.89469,
#   'ath_date': '2021-04-14T11:54:46.763Z',
#   'atl': 67.81,
#   'atl_change_percentage': 84101.80829,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-10-13T18:40:28.096Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
# ...

# %%
market_df = pd.DataFrame(coin_market, columns=['id', 'current_price', 'total_volume', 'market_cap', 'total_supply'])
market_df.set_index('id', inplace=True)
market_df
# Out:
#                  current_price  total_volume     market_cap  total_supply
# id
# bitcoin           57094.000000   39768895774  1075858579885  2.100000e+07
# ethereum           3534.540000   17042871598   416768587252           NaN
# binancecoin         459.730000    4813212971    77280906694  1.681370e+08
# tether                1.000000   66812491416    69786166094  6.958107e+10
# cardano               2.170000    1832154476    69574373610  4.500000e+10
# ...                        ...           ...            ...           ...
# bitclout            114.040000        306055     1205786303  1.080849e+07
# zilliqa               0.092922      64951060     1173029907  2.100000e+10
# telcoin               0.020300      35743645     1159946438  1.000000e+11
# curve-dao-token       2.940000     261443592     1150001070  1.608166e+09
# mina-protocol         4.160000      36453931     1094518974  8.616933e+08
#
# [100 rows x 4 columns]

# %%
top100_df = pd.DataFrame(coin_market, columns=['id', 'ath', 'ath_date', 'atl', 'atl_date'])
top100_df.set_index('id', inplace=True)
top100_df
# Out:
#                           ath                  ath_date        atl  \
# id
# bitcoin          64805.000000  2021-04-14T11:54:46.763Z  67.810000
# ethereum          4356.990000  2021-05-12T14:41:48.623Z   0.432979
# binancecoin        686.310000  2021-05-10T07:24:17.097Z   0.039818
# tether               1.320000  2018-07-24T00:00:00.000Z   0.572521
# cardano              3.090000  2021-09-02T06:00:10.474Z   0.019253
# ...                       ...                       ...        ...
# bitclout           198.680000  2021-06-19T20:53:25.052Z  54.530000
# zilliqa              0.255376  2021-05-06T17:33:45.940Z   0.002396
# telcoin              0.064483  2021-05-11T00:32:24.043Z   0.000065
# curve-dao-token     54.010000  2020-08-14T04:53:44.010Z   0.331577
# mina-protocol        9.090000  2021-06-01T01:42:37.064Z   0.925536
#
#                                  atl_date
# id
# bitcoin          2013-07-06T00:00:00.000Z
# ethereum         2015-10-20T00:00:00.000Z
# ...

# %%
market_df.to_csv('data_files2/market.csv')
top100_df.to_csv('data_files2/top100_ath.csv')

# %%
# Attempt to convert API calls as Json
btc = cg.get_price(
    ids='bitcoin', vs_currencies='usd', include_market_cap='true')

# %%
cg.get_price(
    ids='bitcoin', vs_currencies='usd', include_market_cap='true')

# %%
btc
# Out:
# {'bitcoin': {'usd': 57200, 'usd_market_cap': 1075858579885.2802}}

# %%
import json
import requests
# Returns asset symbols
url = 'https://rest.coinapi.io/v1/symbols'
headers = {'X-CoinAPI-Key' : 'F7939131-318A-4B94-ABF5-9DE208896A2A'}
response = requests.get(url, headers=headers)
json_data = json.loads(response.text)
json_data
# Out:
# [{'symbol_id': 'OKEX_OPT_ETH_USD_210807_2700_C',
#   'exchange_id': 'OKEX',
#   'symbol_type': 'OPTION',
#   'asset_id_base': 'ETH',
#   'asset_id_quote': 'USD',
#   'option_type_is_call': True,
#   'option_strike_price': 2700.0,
#   'option_contract_unit': 1.0,
#   'option_exercise_style': 'EUROPEAN',
#   'option_expiration_time': '2021-08-07T08:00:00.0000000Z',
#   'data_end': '2021-08-07',
#   'data_quote_end': '2021-08-07T07:58:18.0890000Z',
#   'symbol_id_exchange': 'ETH_USD_210807_2700_C',
#   'asset_id_base_exchange': 'ETH',
#   'asset_id_quote_exchange': 'USD'},
#  {'symbol_id': 'OKEX_OPT_BTC_USD_210807_36000_C',
#   'exchange_id': 'OKEX',
#   'symbol_type': 'OPTION',
#   'asset_id_base': 'BTC',
#   'asset_id_quote': 'USD',
#   'option_type_is_call': True,
#   'option_strike_price': 36000.0,
#   'option_contract_unit': 1.0,
#   'option_exercise_style': 'EUROPEAN',
#   'option_expiration_time': '2021-08-07T08:00:00.0000000Z',
#   'data_end': '2021-08-07',
# ...

# %%
# returns all assets
url = 'https://rest.coinapi.io/v1/assets'
headers = {'X-CoinAPI-Key' : 'F7939131-318A-4B94-ABF5-9DE208896A2A'}
response = requests.get(url, headers=headers)
json_data = json.loads(response.text)
json_data
# Out:
# [{'asset_id': 'BTC',
#   'name': 'Bitcoin',
#   'type_is_crypto': 1,
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2021-10-13T19:04:06.9624153Z',
#   'data_orderbook_start': '2014-02-24T17:43:05.0000000Z',
#   'data_orderbook_end': '2020-08-05T14:38:38.3413202Z',
#   'data_trade_start': '2010-07-17T23:09:17.0000000Z',
#   'data_trade_end': '2021-10-13T19:07:39.8370000Z',
#   'data_symbols_count': 66434,
#   'volume_1hrs_usd': 38605481904345.93,
#   'volume_1day_usd': 1725554038332147.8,
#   'volume_1mth_usd': 2.3459298580782223e+18,
#   'price_usd': 57128.00540309832,
#   'id_icon': '4caf2b16-a017-4e26-a348-2cea69c34cba',
#   'data_start': '2010-07-17',
#   'data_end': '2021-10-13'},
#  {'asset_id': 'USD',
#   'name': 'US Dollar',
#   'type_is_crypto': 0,
#   'data_quote_start': '2014-02-24T17:43:05.0000000Z',
#   'data_quote_end': '2021-10-13T19:04:06.6527100Z',
#   'data_orderbook_start': '2014-02-24T17:43:05.0000000Z',
# ...

# %%
# Exchange rate of bitcoin to us dollar
url = 'https://rest.coinapi.io/v1/exchangerate/BTC?invert=false'
headers = {'X-CoinAPI-Key' : 'F7939131-318A-4B94-ABF5-9DE208896A2A'}
response1 = requests.get(url, headers=headers)
json_data1 = json.loads(response.text)
json_data1
# Out:
# {'time': '2021-10-13T19:14:13.0000000Z',
#  'asset_id_base': 'BTC',
#  'asset_id_quote': 'USD',
#  'rate': 57051.74408077559,
#  'src_side_base': [{'time': '2021-10-13T19:14:13.0000000Z',
#    'asset': 'BCH',
#    'rate': 57034.918442084716,
#    'volume': 9560017.511553066},
#   {'time': '2021-10-13T19:14:13.0000000Z',
#    'asset': 'USD',
#    'rate': 57053.70721650988,
#    'volume': 1831212158.1332054},
#   {'time': '2021-10-13T19:14:13.0000000Z',
#    'asset': 'LTC',
#    'rate': 57044.77657631821,
#    'volume': 39566121.833295025},
#   {'time': '2021-10-13T19:14:13.0000000Z',
#    'asset': 'USDT',
#    'rate': 57051.68058546554,
#    'volume': 3388853162.039517},
#   {'time': '2021-10-13T19:14:13.0000000Z',
#    'asset': 'LINK',
#    'rate': 57032.80599093953,
#    'volume': 39914658.89100486},
#   {'time': '2021-10-13T19:14:13.0000000Z',
#    'asset': 'ETH',
#    'rate': 57044.102040924154,
#    'volume': 363966010.0131201},
#   {'time': '2021-10-13T19:14:13.0000000Z',
# ...

# %%
exchanges = api.metadata_list_exchanges()
print('Exchanges')
for exchange in exchanges:
     print('Exchange ID: %s' % exchange['exchange_id'])
# Out:
# Exchanges
# Exchange ID: ECB
# Exchange ID: BINANCE
# Exchange ID: KRAKEN
# Exchange ID: COINBASE
# Exchange ID: BITSTAMP
# Exchange ID: GEMINI
# Exchange ID: LMAXDIGITAL
# Exchange ID: OKCOINCNY
# Exchange ID: HUOBI
# Exchange ID: BITTREX
# Exchange ID: POLONIEX
# Exchange ID: BITFINEX
# Exchange ID: HUOBIPRO
# Exchange ID: HITBTC
# Exchange ID: BTCCHINA
# Exchange ID: BITFLYER
# Exchange ID: BITHUMB
# Exchange ID: COINONE
# Exchange ID: OKEX
# Exchange ID: OKCOINUSD
# Exchange ID: BTCTRADE
# Exchange ID: BITMEX
# Exchange ID: KUCOIN
# Exchange ID: ITBIT
# Exchange ID: DERIBIT
# Exchange ID: BITBAY
# Exchange ID: BINANCEUS
# Exchange ID: BIBOX
# Exchange ID: UPBIT
# Exchange ID: CRYPTOPIA
# Exchange ID: COINCHECK
# Exchange ID: LIQUI
# Exchange ID: EXMO
# Exchange ID: CHBTC
# Exchange ID: JUBI
# Exchange ID: ZAIF
# Exchange ID: KORBIT
# Exchange ID: BTC38
# Exchange ID: MTGOX
# Exchange ID: LAKEBTC
# Exchange ID: BLEUTRADE
# Exchange ID: BITCOINID
# Exchange ID: TIDEX
# ...

# %%
dr_2021_1 = datetime.date(2021, 1, 1).isoformat()
dr_2021_2 = datetime.date(2021, 4, 17).isoformat()
dr_2021_3 = datetime.date(2021, 7, 27).isoformat()
dr_2021_4 = datetime.date(2021, 10, 15).isoformat()

# %%
# Shiba Inu data from Coinbase. Launched on Coinbase in September 2021. 
shiba_inu_ohlcv_1yr_1 = api.ohlcv_historical_data(
    'COINBASE_SPOT_SHIB_USD', {'period_id': '1DAY', 'time_start': dr_2021_3, 'time_end': dr_2021_4})

for period in shiba_inu_ohlcv_1yr_1:
    print('Period start: %s' % period['time_period_start'])
    print('Period end: %s' % period['time_period_end'])
    print('Time open: %s' % period['time_open'])
    print('Time close: %s' % period['time_close'])
    print('Price open: %s' % period['price_open'])
    print('Price close: %s' % period['price_close'])
    print('Price low: %s' % period['price_low'])
    print('Price high: %s' % period['price_high'])
    print('Volume traded: %s' % period['volume_traded'])
    print('Trades count: %s' % period['trades_count'])
# Out:
# Period start: 2021-09-09T00:00:00.0000000Z
# Period end: 2021-09-10T00:00:00.0000000Z
# Time open: 2021-09-09T16:12:34.0036640Z
# Time close: 2021-09-09T23:59:59.9480520Z
# Price open: 1e-05
# Price close: 5.67e-05
# Price low: 6e-06
# Price high: 9e-05
# Volume traded: 2011322981294.0
# Trades count: 161578
# Period start: 2021-09-10T00:00:00.0000000Z
# Period end: 2021-09-11T00:00:00.0000000Z
# Time open: 2021-09-10T00:00:01.8385470Z
# Time close: 2021-09-10T23:59:58.8039630Z
# Price open: 5.67e-05
# Price close: 7.02e-06
# Price low: 6.76e-06
# Price high: 6e-05
# Volume traded: 3802508965310.0
# Trades count: 174959
# Period start: 2021-09-11T00:00:00.0000000Z
# Period end: 2021-09-12T00:00:00.0000000Z
# Time open: 2021-09-11T00:00:02.1697600Z
# Time close: 2021-09-11T23:59:51.6247650Z
# Price open: 7.02e-06
# Price close: 6.77e-06
# Price low: 6.73e-06
# Price high: 7.35e-06
# Volume traded: 1663194647440.0
# Trades count: 56937
# Period start: 2021-09-12T00:00:00.0000000Z
# ...

# %%
shiba_df = pd.DataFrame(shiba_inu_ohlcv_1yr_1).drop(
    columns=['time_open', 'time_close', 'time_period_end']).rename(
    {'time_period_start': 'start_date'}, axis='columns')
shiba_df.set_index('start_date')
# Out:
#                               price_open  price_high  price_low  price_close  \
# start_date
# 2021-09-09T00:00:00.0000000Z    0.000010    0.000090   0.000006     0.000057
# 2021-09-10T00:00:00.0000000Z    0.000057    0.000060   0.000007     0.000007
# 2021-09-11T00:00:00.0000000Z    0.000007    0.000007   0.000007     0.000007
# 2021-09-12T00:00:00.0000000Z    0.000007    0.000007   0.000007     0.000007
# 2021-09-13T00:00:00.0000000Z    0.000007    0.000007   0.000006     0.000006
# 2021-09-14T00:00:00.0000000Z    0.000006    0.000007   0.000006     0.000007
# 2021-09-15T00:00:00.0000000Z    0.000007    0.000007   0.000007     0.000007
# 2021-09-16T00:00:00.0000000Z    0.000007    0.000013   0.000007     0.000009
# 2021-09-17T00:00:00.0000000Z    0.000009    0.000010   0.000008     0.000008
# 2021-09-18T00:00:00.0000000Z    0.000008    0.000009   0.000008     0.000008
# 2021-09-19T00:00:00.0000000Z    0.000008    0.000008   0.000007     0.000008
# ...

# %%
shiba_df.to_csv('data_files/shiba_2021.csv')
